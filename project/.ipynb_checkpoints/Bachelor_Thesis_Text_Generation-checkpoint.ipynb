# %% [markdown]
# ![](images/ohm_logo.png)
#
# <h1><center>Bachelor Thesis</center></h1>
#
# <h1><center><big>IT-Based textgeneration using NLP methods</big><br><hr> <i>State-of-the-art and design of a prototype </i></center></h1>
#
# <center>from Tim Löhr</center>

# %% [markdown]
# # 1.0 Importing the Dependcies

# %%
from attention import AttentionLayer

import numpy as np  
import pandas as pd 
import re           
from bs4 import BeautifulSoup 

from nltk.corpus import stopwords   
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer

from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras import backend as K 

from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.model_selection import train_test_split


import matplotlib.pyplot as plt

import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2.0 Loading the Data

# %%
data = pd.read_csv('amazon-fine-food-reviews/Reviews.csv', nrows=5000)
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary  \
# 0  Good Quality Dog Food
# 1      Not as Advertised
# 2  "Delight" says it all
# 3         Cough Medicine
# 4            Great taffy
#
#                                                                                                                                                                                                       Text
# 0  I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labr...
# 1           Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 2  This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with ...
# 3  If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The fl...
# 4                                                             Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.

# %%
data.shape
# Out:
# (5000, 10)

# %% [markdown]
# # 3.0 Data Preprocessing

# %%
#data = data[['Summary', 'Text']]

# %%
data.drop_duplicates(subset='Text')
data.dropna(axis=0, inplace=True)

# %%
data.shape
# Out:
# (5000, 10)

# %% [markdown]
# ### Contraction Mapping

# %%
from contraction_mapping import contraction_mapping

contraction_mapping = contraction_mapping()

# %% [markdown]
# ## Cleaning
#
# ### Text Cleaning

# %%
stop_words = stopwords.words('english')
tokenizer = RegexpTokenizer(r'\w+')

def text_cleaner(text):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    tokens = [w for w in newString.split() if not w in stop_words]
    long_words=[]
    for i in tokens:
        if len(i)>=3:                  #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()

# %%
#text_cleaner(data['Text'][127])

# %%
#data['Text'][127]

# %% [markdown]
# #### Cleaned text concatenate with DataFrame

# %%
cleaned_text = []
for t in data['Text']:
    cleaned_text.append(text_cleaner(t))

# %% [markdown]
# ### Summary Cleaning

# %%
data['Summary'][:10]
# Out:
# 0                            Good Quality Dog Food
# 1                                Not as Advertised
# 2                            "Delight" says it all
# 3                                   Cough Medicine
# 4                                      Great taffy
# 5                                       Nice Taffy
# 6    Great!  Just as good as the expensive brands!
# 7                           Wonderful, tasty taffy
# 8                                       Yay Barley
# 9                                 Healthy Dog Food
# Name: Summary, dtype: object

# %%
def summary_cleaner(text):
    newString = re.sub('"','', text)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString)
    newString = newString.lower()
    tokens=newString.split()
    newString=''
    for i in tokens:
        if len(i)>1:                                 
            newString=newString+i+' '  
    return newString

# %%
cleaned_summary = []
for t in data['Summary']:
    cleaned_summary.append(summary_cleaner(t))

data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary
data['cleaned_summary'].replace('', np.nan, inplace=True)
data.dropna(axis=0,inplace=True)

data['cleaned_summary'] = data['cleaned_summary'].apply(lambda x: '_START_ ' + x + ' _END_')

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary  \
# 0  Good Quality Dog Food
# 1      Not as Advertised
# 2  "Delight" says it all
# 3         Cough Medicine
# 4            Great taffy
#
#                                                                                                                                                                                                       Text  \
# 0  I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labr...
# 1           Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 2  This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with ...
# 3  If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The fl...
# 4                                                             Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.
#
#                                                                                                                                                                                               cleaned_text  \
# 0                                     bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better
# 1                                                                    product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo
# 2  confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat famil...
# 3                                                                              looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal
# 4                                                                                                                      great taffy great price wide assortment yummy taffy delivery quick taffy lover deal
#
#                         cleaned_summary
# 0  _START_ good quality dog food  _END_
# 1      _START_ not as advertised  _END_
# 2    _START_ delight says it all  _END_
# 3         _START_ cough medicine  _END_
# 4            _START_ great taffy  _END_

# %% [markdown]
# ### Distribution of the sequences

# %%
text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in data['Text']:
      text_word_count.append(len(i.split()))

for i in data['Summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})
length_df.hist(bins = 30)
plt.show()

# %%
max_len_text=80 
max_len_summary=10

# %% [markdown]
# ### Preparing Tokenizer

# %%
X_train , X_test , y_train , y_test = train_test_split(data['cleaned_text'], data['cleaned_summary'], test_size=0.1, random_state=0, shuffle=True)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4497,)
# (500,)
# (4497,)
# (500,)

# %% [markdown]
# #### Text Tokenizer

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(X_train))

#convert text sequences into integer sequences
X_train = x_tokenizer.texts_to_sequences(X_train) 
X_test = x_tokenizer.texts_to_sequences(X_test)

#padding zero upto maximum length
X_train = pad_sequences(X_train,  maxlen=max_len_text, padding='post') 
X_test = pad_sequences(X_test, maxlen=max_len_text, padding='post')

x_voc_size = len(x_tokenizer.word_index) +1

# %% [markdown]
# #### Summary Tokenizer

# %%
#preparing a tokenizer for summary on training data 
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(y_train))

#convert summary sequences into integer sequences
y_train = y_tokenizer.texts_to_sequences(y_train) 
y_test = y_tokenizer.texts_to_sequences(y_test) 

#padding zero upto maximum length
y_train = pad_sequences(y_train, maxlen=max_len_summary, padding='post')
y_test = pad_sequences(y_test, maxlen=max_len_summary, padding='post')

y_voc_size = len(y_tokenizer.word_index) +1

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4497, 80)
# (500, 80)
# (4497, 10)
# (500, 10)

# %% [markdown]
# # 4.0 Model

# %%
K.clear_session() 
latent_dim = 500 

# Encoder 
encoder_inputs = Input(shape=(max_len_text,)) 
enc_emb = Embedding(x_voc_size, latent_dim,trainable=True)(encoder_inputs) 

#LSTM 1 
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True) 
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb) 

#LSTM 2 
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True) 
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1) 

#LSTM 3 
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True) 
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2) 

# Set up the decoder. 
decoder_inputs = Input(shape=(None,)) 
dec_emb_layer = Embedding(y_voc_size, latent_dim,trainable=True) 
dec_emb = dec_emb_layer(decoder_inputs) 

#LSTM using encoder_states as initial state
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True) 
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c]) 

#Attention Layer
attn_layer = AttentionLayer(name='attention_layer') 
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs]) 

# Concat attention output and decoder LSTM output 
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#Dense layer
decoder_dense = TimeDistributed(Dense(y_voc_size, activation='softmax')) 
decoder_outputs = decoder_dense(decoder_concat_input) 

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 80, 500)      6052000     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 80, 500), (N 2002000     embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 80, 500), (N 2002000     lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 500)    1449000     input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 80, 500), (N 2002000     lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 500),  2002000     embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 500),  500500      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 1000)   0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 2898)   2900898     concat_layer[0][0]
# ==================================================================================================
# Total params: 18,910,398
# Trainable params: 18,910,398
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Model optimization

# %%
model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy')

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

# %% [markdown]
# #### Model fitting

# %%
history=model.fit([X_train, y_train[:,:-1]], 
                  y_train.reshape(y_train.shape[0],y_train.shape[1], 1)[:,1:],
                  epochs=10,
                  callbacks=[es],
                  batch_size=256, 
                  validation_data=([X_test,y_test[:,:-1]], y_test.reshape(y_test.shape[0],y_test.shape[1], 1)[:,1:]))
# Out:
# Train on 4497 samples, validate on 500 samples
# Epoch 1/10
# 4497/4497 [==============================] - 138s 31ms/sample - loss: 4.2990 - val_loss: 2.8574
# Epoch 2/10
# 4497/4497 [==============================] - 133s 30ms/sample - loss: 3.1555 - val_loss: 2.5769
# Epoch 3/10
#  256/4497 [>.............................] - ETA: 1:57 - loss: 2.9847

# %% [markdown]
# # 5.0 Evaluation

# %%
plt.plot(history.history['loss'], label='train') 
plt.plot(history.history['val_loss'], label='test') 
plt.legend()
plt.show()

# %%
reverse_target_word_index=y_tokenizer.index_word 
reverse_source_word_index=x_tokenizer.index_word 
target_word_index=y_tokenizer.word_index

# %% [markdown]
# #### Inference

# %%
# encoder inference
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# decoder inference
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_len_text,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs)

# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat)

# Final decoder model
decoder_model = Model(
[decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
[decoder_outputs2] + [state_h2, state_c2])

# %% [markdown]
# #### Inference Process

# %%
reverse_target_word_index[0] = 'start'

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))

    # Chose the 'start' word as the first word of the target sequence
    target_seq[0, 0] = target_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]

        if(sampled_token!='end'):
            decoded_sentence += ' '+sampled_token

            # Exit condition: either hit max length or find stop word.
            if (sampled_token == 'end' or len(decoded_sentence.split()) >= (max_len_summary-1)):
                stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    
    newString=''
    
    for i in input_seq:
        
        if((i!=0 and i!= target_word_index['start']) and i != target_word_index['end']):
            
            newString=newString+reverse_target_word_index[i] + ' '
            
    return newString

def seq2text(input_seq):
    
    newString=''
    
    for i in input_seq:
        
        if(i!=0):
            newString=newString+reverse_source_word_index[i] + ' '
            
    return newString

# %%
for i in range(len(X_test)):
    print("Review:",seq2text(X_test[i]))
    print("Original summary:", seq2summary(y_test[i]))
    print("Predicted summary:", decode_sequence(X_test[i].reshape(1,max_len_text)))
    print("\n")
# Out:
# Review: use raw sugar seem little smaller normal crystals still good buy
# Original summary: good product
# Predicted summary:  great start start start start start start start start
#
#
# Review: wonderful candy hard find got huge bag put freezer came shipped nicely sturdy box heavy plastic great
# Original summary: great candy
# Predicted summary:  great start start start start start start start start
#
#
# Review: offer great price great taste thanks amazon selling product
# Original summary: this is my taste
# Predicted summary:  great start start start start start start start start
#
#
# Review: product impossible wash actually get cleaned could get food pieces save life tried scrubbing even
# Original summary: only good for
# Predicted summary:  great start start start start start start start start
#
#
# Review: always liked salt vinegar chips time stronger flavor bottom bag vinegar right first chip stop finished bag addictive like salt vinegar ultimate chips nothing else compares
# Original summary: the for salt and vinegar chips
# Predicted summary:  great start start start start start start start start
#
#
# Review: sauce world types regular mild raw fish light colored bluegrass soy sauce regular style compared bluegrass starts flat middle ends complex interesting flavor less salty round full flavor middle complex flavors saltiness bluegrass minus full middle flavor plus especially dipping sushi flavor lived japan many years used standard japanese flavor tried bluegrass blended food flavor soy sauce usually used bluegrass perfectly good soy sauce brand different flavor everyone favorite want unique gift asian friend different standard bottle bourbon box chocolate
# Original summary: soy sauce but not special good as unique gift
# Predicted summary:  great start start start start start start start start
#
#
# Review: son bought package jalapeno potato chips couple weeks ago become addicted first kettle chips appear somewhat better terms fats etc many chips one dietary information second individual chips nice crisp good crunch value munch away third jalapeno kick many products spicy kick bland get slow noticeable burn jalapeno preference bit heat understand consumers would prefer somewhat less would still decent spicyness pretty happy product weeks since first bought purchase package week local grocery store
# Original summary: pretty tasty and spiced
# Predicted summary:  great start start start start start start start start
#
#
# Review: received shown mother law likes quit carrying great could get amazon
# Original summary: altoids
# Predicted summary:  great start start start start start start start start
#
#
# Review: strawberry twist long lasting pleasant flavor sweet excessively delivery timely price right trident flavors though bad either next pick would blueberry
# Original summary: has very good flavor
# Predicted summary:  great start start start start start start start start
#
#
# Review: purchased sale terms energy provides works taste leaves something tried mixing water make
# Original summary: doesn taste that good but you the energy
# Predicted summary:  great start start start start start start start start
#
#
# Review: tea drinking honestly say best earl grey ever tasted ordered number times batch consistently excellent even given gift container superb keeping loose tea fresh inner lid tea stays dry fresh length time takes use favor like earl grey treat tea
# Original summary: favorite earl grey tea
# Predicted summary:  great start start start start start start start start
#
#
# Review: would even think buying product unless know price per unit compare items online store
# Original summary: what quantity is it
# Predicted summary:  great start start start start start start start start
#
#
# Review: love asparagus recently never pickled asparagus goodness friend introduced exact brand could believe great stuff tasted loved much bought six pack got jars left gonna need
# Original summary:
# Predicted summary:  great start start start start start start start start
#
#
# Review: year old male cat chronic urinary tract feed dry food combination wet food combination seems keeps control switch another type dry food gets worse cats seem enjoy food well expensive seems best solution
# Original summary: good for
# Predicted summary:  great start start start start start start start start
#
#
# Review: son severe allergies item loves convenience feel good giving taste great
# Original summary: my loves them
# Predicted summary:  great start start start start start start start start
#
#
# Review: good quality brand chocolate many one tasty fast delivery
# Original summary: caramel chocolate
# Predicted summary:  great start start start start start start start start
#
#
# Review: rarely eat chips saw tried really amazing love cheddar chips really thin crunch delicious flavor recommend
# Original summary: amazing chips
# Predicted summary:  great start start start start start start start start
#
#
# Review: backyard bbq kettle chips great deal code nice larger size bag kettle chips grocery store ounces polish one family lunch arrived fresh chips amazon grocery great flavor natural
# Original summary: great deal
# Predicted summary:  great start start start start start start start start
#
#
# Review: someone brought party last month put full think anyone would like potato chips last week friends pantry put gosh good wrong think would bland full real potato flavor wonderfully crisp fresh tasting amazon buy case want dips truly delicious
# Original summary: do not miss the salt
# Predicted summary:  great start start start start start start start start
#
#
# Review: strawberry twizzlers guilty pleasure yummy six pounds around son
# Original summary: strawberry twizzlers yummy
# Predicted summary:  great start start start start start start start start
#
#
# Review: kind tea good taste smell like tea feel like thing chemical
# Original summary: of tea don get it
# Predicted summary:  great start start start start start start start start
#
#
# Review: glad amazon carried hard time finding elsewhere unique size need garage door great deal price
# Original summary: great for the price
# Predicted summary:  great start start start start start start start start
#
#
# Review: use like asian dishes least week love product fast shipping usual would buy
# Original summary: sauce
# Predicted summary:  great start start start start start start start start
#
#
# Review: seems little wholesome supermarket brands somewhat mushy quite much flavor either pass kids probably buy
# Original summary: oatmeal
# Predicted summary:  great start start start start start start start start
#
#
# Review: absolutely husband love however another customer put expensive ship cost shipping
# Original summary: tartlets
# Predicted summary:  great start start start start start start start start
#
#
# Review: eat mustard everything hands best mustard ever tried fact everyone tell try falls love well spicy tasty real quality like spicy mustard love
# Original summary: yummy
# Predicted summary:  great start start start start start start start start
#
#
# Review: found product kettle chips unsalted fabulous found accident amazon hunting local stores crisp tasty without salt
# Original summary: kettle chips
# Predicted summary:  great start start start start start start start start
#
#
# Review: awful thought food supposed taste good eat ice cream afterwards get taste mouth bad
# Original summary: awful
# Predicted summary:  great start start start start start start start start
#
#
# Review: favorite hot sauce use give anything extra flavor loved going favorite town seeing offering great product really enjoy putting breakfast burritos
# Original summary: great hot sauce
# Predicted summary:  great start start start start start start start start
#
#
# Review: new favorite always fan salt vinegar honey new number one strong taste loving honey mustard flavor must hope like price wise see much deal purchased grocery shipping would given product stars price taste fabulous disappointed
# Original summary: best chips out there
# Predicted summary:  great start start start start start start start start
#
#
# Review: mother father wonderful pieces chocolate heaven believe receiving know deserve receive
# Original summary: chocolate
# Predicted summary:  great start start start start start start start start
#
#
# Review: used pioneer gravy number years easy make tastes great also goes well potatoes meats etc try
# Original summary: gravy is great
# Predicted summary:  great start start start start start start start start
#
#
# Review: roast large iron pan grill smell wonderful roasted beans taste delicious importantly coffee smooth bitter aftertaste numerous send roasted beans home friends like much
# Original summary: our love it
# Predicted summary:  great start start start start start start start start
#
#
# Review: love earth best organic baby food tastiest one tried think pretty gross daughter still eats much flavors got decent amount protein important vegetarian family
# Original summary: good for you but not best flavor
# Predicted summary:  great start start start start start start start start
#
#
# Review: yes good however absolutely flavoring stuff satisfying becomes much certainly good general nutritional issues package cannot opened without sharp could pull apart top used normally carry knife scissors rodent teeth well hungry able rip bag using car even bag wow thick tough package says krinkle cut chips turns means kind wanted eat ridged style chips take skin roof mouth information important good brands problems
# Original summary: you to know
# Predicted summary:  great start start start start start start start start
#
#
# Review: chips honey dijon kettle chips sea salt vinegar honey dijon chips bring terrific balance salty tangy sweet crunchy brands tried use much mustard flavor overpowers honey dijon pairing honey dijon chips make great side dish bbq plate baked beans coleslaw potato salad grilled meat naturally also great beer sea salt vinegar chips perfect complement vegetable trays cucumber carrot celery cherry tomatoes skip dip balance tangy chips alternating bites raw vegetable summary highly recommend kettle brand chips great buy amazon com
# Original summary: one bite and you will become chippoisseur
# Predicted summary:  great start start start start start start start start
#
#
# Review: daughter baby food still eat tried foods like texture really good likes keep buying
# Original summary: favorite
# Predicted summary:  great start start start start start start start start
#
#
# Review: need salt hide taste potato chips chips taste potato comes instead still snack food salt trans fats mean healthiest potato chips get low salt diet available means eat chips kettle best
# Original summary: the best chips
# Predicted summary:  great start start start start start start start start
#
#
# Review: many healthy products taste good taste good first try chips one tasty served guests twice times wanted know get also nice something gluten free friends diabetic would eat anyway
# Original summary: very tasty chips
# Predicted summary:  great start start start start start start start start
#
#
# Review: great candy family loved smaller thought expensive small however germany get easier shipping usa makes great product fun usa family receive
# Original summary: great candy my loved it
# Predicted summary:  great start start start start start start start start
#
#
# Review: loved mold could used one last use make daughter first birthday going way mold could would liked kept use price matter much served main purpose
# Original summary: could use only
# Predicted summary:  great start start start start start start start start
#
#
# Review: hits spot apples turkey add want take next level cannot find non non dried even better food stores apples carrots turkey taste good month old growing twin girls babies love carrots since sweet taste made great addition whole flour absorbs water give acceptable consistency ingredients per label water organic apples organic carrots mechanically separated organic turkey organic whole flour addition protein vitamin calcium iron pleased babies like food introduced many foods earth best informed percentage daily needs met based adult
# Original summary: and
# Predicted summary:  great start start start start start start start start
#
#
# Review: started drinking power slim tea diet help curb since liked well tried others hooked satisfying drink time energy gives extra pick afternoons helps keep going day matter long
# Original summary: love this tea
# Predicted summary:  great start start start start start start start start
#
#
# Review: package came label torn cooking instructions know normally cook couscous tried cup water cup couscous brought boil let sit covered min mushy tasteless thrown rest container
# Original summary: very
# Predicted summary:  great start start start start start start start start
#
#
# Review: taste really good purchasing different brand similar taste texture agree reviewer ordering summer packaging ice packs melt warm weather like chocolate food items order cold weather buy enough last
# Original summary: taste great
# Predicted summary:  great start start start start start start start start
#
#
# Review: real good product love chips customers cannot wrong best
# Original summary: good buy
# Predicted summary:  great start start start start start start start start
#
#
# Review: pocky incredibly good snack impressed asia packaging ordered something easy melt chocolate dead heat summer top package dessert pocky ordered weather melted liquid goo course expecting pocky boxes melted away took special care put pocky box reading protect heat pocky arriving perfect condition love asia anything
# Original summary: yummy
# Predicted summary:  great start start start start start start start start
#
#
# Review: ordered line received days tea excellent price right
# Original summary: good tea
# Predicted summary:  great start start start start start start start start
#
#
# Review: would continue buy moving home made finger foods away glass jars many like flavors though great textures
# Original summary: organic and tasty
# Predicted summary:  great start start start start start start start start
#
#
# Review: kettle foods inc makes best tasting potato chips ever eaten variety flavors classic barbeque unique spicy thai find right flavor mouth taste wonderful natural chips cooked safflower sunflower oil zero cholesterol product week kettle foods inc green giant company environmental convert waste oils power company roof top system production energy buying energy future care present eco system recent building construction earned gold rating energy environmental design mouth thank environment
# Original summary: yummy
# Predicted summary:  great start start start start start start start start
#
#
# Review: nothing good bad chips like plain potato chips would like thicker brands fresh box crunchy salty one bag lot generally cannot finish part reason oily taste oil bit overwhelming used spicy chips may like since spice except salt name says think buy best date bags ordered end october
# Original summary: kettle chips sea salt
# Predicted summary:  great start start start start start start start start
#
#
# Review: looks pretty contents minute seem high quality plastic cup tea looks like came dollar store basket nice though
# Original summary: even at little overpriced
# Predicted summary:  great start start start start start start start start
#
#
# Review: product great job helped make husband feel lots better even though early failure
# Original summary: for your health
# Predicted summary:  great start start start start start start start start
#
#
# Review: chips greasy taste burnt grease bottom bag chips saturated especially bottom bag even trans fat free need lot less greasy
# Original summary: chips
# Predicted summary:  great start start start start start start start start
#
#
# Review: three jars came form edible babies rest filled would mix water also brown color brown like jars good mixture pretty disappointing waste money
# Original summary: had to out of jars
# Predicted summary:  great start start start start start start start start
#
#
# Review: like tea variety certainly enjoy appreciate tea happy find ahmad teas available surprised negative review years drinking ahmad teas even disappointed superb quality ahmad teas remained consistent throughout years current deal pack good highly recommended note description confusing packet tea grams equals pounds ounces
# Original summary: excellent loose tea
# Predicted summary:  great start start start start start start start start
#
#
# Review: gravy mix excellent except use water called use milk instead makes better
# Original summary: wonderful gravy
# Predicted summary:  great start start start start start start start start
#
#
# Review: sugar good use coffee cereal etc week never back white sugar white sugar taste terrible plus read raw sugar contains lot missing diets product delivered fast well packaged complaint price wish could find raw sugar cheaper would happy buy bulk found
# Original summary: you ll never use white sugar
# Predicted summary:  great start start start start start start start start
#
#
# Review: purchased coffee mate singles use work along coffee tea bags great require
# Original summary: perfect for
# Predicted summary:  great start start start start start start start start
#
#
# Review: agree company natural tried small bag local store immediately bought bulk online save percent flavor strong best food mild flavor like vegetables plain whole grain bread otherwise compete food
# Original summary: great strong flavor
# Predicted summary:  great start start start start start start start start
#
#
# Review: hard get husband eat breakfast school takes two bars happy often hard find flavor local grocery stores amazon com came reasonable price came keep husband breakfast ready runs door mornings often like bar evening night snack
# Original summary: favorite
# Predicted summary:  great start start start start start start start start
#
#
# Review: plocky tortilla chips red beans rice ounce bag first tasted chips visiting available live ordered amazon wow friends family addicted spicy flavor first bite bag open gone
# Original summary: these chips are addictive
# Predicted summary:  great start start start start start start start start
#
#
# Review: although several ones taste fine mostly use make vegan sauces recipes call running food processor look perfect anyways price great deal
# Original summary: not the quality but good for the price
# Predicted summary:  great start start start start start start start start
#
#
# Review: chemical sensitive well sugar free using product year use maybe week drink bottle boost energy hour two depending feel replace coffee sweet early afternoon start fade drink full bottle drinking guayaki yerba mate teas years compared many toxic energy highly recommend product clean leave nasty behind body try review everyone body reacts differently
# Original summary: best energy shot for me
# Predicted summary:  great start start start start start start start start
#
#
# Review: husband absolutely love texture light crispy rather thick crunchy actually usually prefers hearty cruncy chip flavor fantastic bean rice corn base makes incredibly flavorful touch onion garlic addition amount never ever like plain chips eat without anything else although particularly amazing fresh salsa highly recommend
# Original summary: perfect tortilla chip goodness
# Predicted summary:  great start start start start start start start start
#
#
# Review: pork tasty time dry pork usually dry meat extreme possibly shipping frozen keeping frozen problem
# Original summary:
# Predicted summary:  great start start start start start start start start
#
#
# Review: one best lemon juice tried customer due high quality product season fresh one need citrus kitchen continue buying
# Original summary: excellent juice
# Predicted summary:  great start start start start start start start start
#
#
# Review: best way cook roast local grocery went could find product till looked please continue keep product available
# Original summary: best roast ever
# Predicted summary:  great start start start start start start start start
#
#
# Review: using mushrooms cooking twenty plus years roland extra fancy purchased best ever used including mushrooms bought italy back usa
# Original summary: an excellent product
# Predicted summary:  great start start start start start start start start
#
#
# Review: love tasty think addicted buying packs bags reasonable going target getting bag savings bag use subscribe save several product love subscribe save
# Original summary: love these
# Predicted summary:  great start start start start start start start start
#
#
# Review: low glycemic index diet help control blood sugar levels recommended agave nectar sweetener since index low opposed honey low sugar mid tried supermarkets health food stores prices usually around bottle ish used like honey substitute every sugar reduce liquids also use carrot cake recipe instead sugar substitute whole wheat flour instead white flour liquids delicious would never know actually good
# Original summary: best price on agave nectar that have found
# Predicted summary:  great start start start start start start start start
#
#
# Review: buying quaker oats granola bars nature valley chewy bars better tasting make great snack chocolate peanuts get better
# Original summary: my new bar
# Predicted summary:  great start start start start start start start start
#
#
# Review: spicy version ketchup bad expensive regular version sweet dessert horrible organic much better flavor costs lot less even heinz organic better deal gave three stars instead two glass plastic
# Original summary: disappointing
# Predicted summary:  great start start start start start start start start
#
#
# Review: twin girls loved vegetable turkey dinner one favorite baby foods great price
# Original summary: love it
# Predicted summary:  great start start start start start start start start
#
#
# Review: hands absolute best salt vinegar chips buy great strong flavor left addicted certainly favorite chips highly recommend trying
# Original summary: the salt vinegar
# Predicted summary:  great start start start start start start start start
#
#
# Review: things darn like lot flavor love otherwise overdose goodness
# Original summary: too much flavor
# Predicted summary:  great start start start start start start start start
#
#
# Review: kettle chips flavors hit miss flavors terrible simple delicious probably one best flavors pros thick crunchy potato chips light salt compromise taste eco friendly business giving occasional burnt chip bag pain open pull time end entire side bag use scissors instead
# Original summary: one of their best flavors
# Predicted summary:  great start start start start start start start start
#
#
# Review: always pleased amazon packaging chips never crushed broken always fresh really liked brand flavor chips tasty
# Original summary: great chips
# Predicted summary:  great start start start start start start start start
#
#
# Review: bought chips wanted try tasty sure unique different flavor right thickness remains crunchy spicy flavorful hint tabasco sauce heat rice granules tortilla chips however spices lacking chip liked much would recommend anyone wants try red beans rice tortilla chips ahead put ingredients nachos except cheese maybe shredded meat tomatoes
# Original summary: plocky rice and beans tortilla chips
# Predicted summary:  great start start start start start start start start
#
#
# Review: excited thinking favorite kettle flavor disappointed opened box found keeping would ordered bags flavor good bbq chip could get flavor grocery store favorite food items always get one star country bbq start chip chip
# Original summary: wrong flavor bbq of chipotle
# Predicted summary:  great start start start start start start start start
#
#
# Review: bought strawberry extract hoping strawberry wine ended less flavor would original expected indeed good strawberry flavor add sugary concoction either give strawberry flavor everyone lips interested found right addition liquid volume extract per gallon liquid
# Original summary: taste tested by
# Predicted summary:  great start start start start start start start start
#
#
# Review: priced well pack baking used top waffles pancakes small added oatmeal little goes long way using agave nectar use less agave nectar would another sweetener cut heat oven degrees oil recipe cut additionally baking make sure mix wet ingredients prior adding dry might already know remember read recipes first sugar typically added dry ingredients agave nectar like sugars able substitute corn syrup making hard candy however highly recommend baking makes everything looking less caramel flavor need use light version product
# Original summary: caramel flavor excellent for baking and for agave too
# Predicted summary:  great start start start start start start start start
#
#
# Review: father could longer take care year old cocker spaniel decided take family brought ear also slightly overweight check vet decided try royal canin based numerous good reviews within week ear problems gone dropped good amount weight going food feeding
# Original summary: perfect for
# Predicted summary:  great start start start start start start start start
#
#
# Review: buy order case cannot even remember first time tasted stuffed olive tried several brands online brand favorite
# Original summary: best by the
# Predicted summary:  great start start start start start start start start
#
#
# Review: eat many chips love great buy arrived quick packed great expiration date ways away awhile enjoy great natural potato flavor love brown russet hardy flavor fit description
# Original summary: great chip
# Predicted summary:  great start start start start start start start start
#
#
# Review: salt vinegar chips favorite flavor think tried every brand far best also like sodium content high like others excessively greasy seem right balance salt vinegar taste
# Original summary: best salt vinegar chips out there
# Predicted summary:  great start start start start start start start start
#
#
# Review: first love packaging making would problem ordered winter cold also want thank free sample delicious love
# Original summary: this item is awesome
# Predicted summary:  great start start start start start start start start
#
#
# Review: found new spring pop tarts bought whim kids amazed delighted fun pop tarts fantastic school snacks lunch boxes school treats tie bright thinking spring gift finding stores way fantastic product
# Original summary: of
# Predicted summary:  great start start start start start start start start
#
#
# Review: like thick chips trans fat natural according bag flavor subjective thing bags keep eating much one time set limit bag cons another reviewer said lot oil chips place paper napkin plate pour chips wait mins eating napkin soak oil seems gross much oil chip napkin soak true least way get rid oil
# Original summary: excellent
# Predicted summary:  great start start start start start start start start
#
#
# Review: use rotel mild love product much daily basis trying cook lower fat healthier foods hurry stuff makes much easier ever notice canned weird tin taste make sauce whatever reason product tastes good beans heat eat add chili powder chili soup also make indian dishes sauce also prefer canned salsas works things like liquid none local grocery stores carry carry anything like pay amazon price order case like paying higher price love love love product
# Original summary: me on
# Predicted summary:  great start start start start start start start start
#
#
# Review: kettle chips spicy thai potato chips perfect amount sweet savory spicy everything would want good meal better yet potato chip since kettle cooked chips shaped sometimes bit browned however sliced perfectly thick thin actually get great crunch bite without breaking tooth flavor although would describe thai sweet tangy flavor kick every get great big hit ginger like spice really overly spicy people handle fact chips absolutely artificial ingredients trans fat makes fabulous addition muncher snack cupboard
# Original summary: tangy spicy and sweet my
# Predicted summary:  great start start start start start start start start
#
#
# Review: stuff really works cramping middle rides pop water bottle set flavor fine goes easy
# Original summary: great for
# Predicted summary:  great start start start start start start start start
#
#
# Review: introduced daughter earth best organic turkey vegetable dinner months bit early weeks loved first bought every kind least favorite tried well also least favorite
# Original summary: my daughter most else this is not her thing
# Predicted summary:  great start start start start start start start start
#
#
# Review: everyone family except one really likes taste addicting year old
# Original summary: delicious
# Predicted summary:  great start start start start start start start start
#
#
# Review: love product best natural sweetener ever tried tried many use also pancake syrup substitute honey peanut butter honey sandwich last long time good value
# Original summary: the best
# Predicted summary:  great start start start start start start start start
#
#
# Review: long story short tasty purchased number flavors brand favorite noted another reviewer contain msg form yeast extract become popular means msg different things person use caution consume find whole process plain site also bag large half air may well help shipping paying premium price organic seems deceptive
# Original summary: very tasty but beware
# Predicted summary:  great start start start start start start start start
#
#
# Review: organic valley organic cheddar cheese organic salt sodium mildly flavored whole wheat cheese dinner cheese wonderful food pasta excellent flavor artificial flavors colors preservatives pasta produced without persistent pesticides pasta simple make wonderful texture servings per box serving contains fat sat fat sodium carb fiber sugars protein however cheese exactly even add butter milk yogurt add wonderful rich smooth cheese flavor cheese add organic cheese cheese packet falls flat flavor contain amount coat pasta give cheese packaging organic texture flavor
# Original summary: organic whole white cheddar cheese oz
# Predicted summary:  great start start start start start start start start
#
#
# Review: bags lot overcooked brown pieces also felt greasy keep fingers napkin
# Original summary:
# Predicted summary:  great start start start start start start start start
#
#
# Review: experienced allergies forms itching dog foods cheap buy anywhere food crazy preservatives cause health problems food works wonders allergies dog loves food
# Original summary: great allergy sensitive dog food dogs love it
# Predicted summary:  great start start start start start start start start
#
#
# Review: used buy sugar years eat much sugar still sugar called sugar misleading picked brand says real sugar brands sugar brown colored caramel something find needed sweet water days ago put sugar raw glass water became brown bottom glass got pure white sugar crystals shame try put sugar mouth seconds pure white crystals well wondering consumers hold company practice
# Original summary:
# Predicted summary:  great start start start start start start start start
